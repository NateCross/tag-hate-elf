# %% [markdown]
# # CountVec from scratch
#
# Based on [this tutorial](https://medium.com/@saivenkat_/implementing-countvectorizer-from-scratch-in-python-exclusive-d6d8063ace22)

# %% [markdown]
# ## Part 1: Get unique words and their index

# %%
import pandas as pd
import numpy as np
# Out:
# /tmp/ipykernel_23009/2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
csv = pd.read_csv('../datasetall.csv')

csv
# Out:
#                                                     text  label  Unnamed: 2
# 0      Binay: Patuloy ang kahirapan dahil sa maling p...      0         NaN
# 1      SA GOBYERNONG TAPAT WELCOME SA BAGUO ANG LAHAT...      0         NaN
# 2      wait so ur telling me Let Leni Lead mo pero NY...      1         NaN
# 3       [USERNAME]wish this is just a nightmare that ...      0         NaN
# 4                   doc willie ong and isko sabunutan po      0         NaN
# ...                                                  ...    ...         ...
# 28456    Bisaya, Probinsyano/a, mostly Bisaya = katulong      1         NaN
# 28457  Amnesia. In my whole life wala pa ako nakasala...      1         NaN
# 28458  Kontrabida na ilang beses na tinalo at obvious...      1         NaN
# 28459  Yung antagonist laging kailangang sobrang sama...      1         NaN
# 28460  May nabaril or nasaksak na pero 'di pa tatawag...      1         NaN
#
# [28461 rows x 3 columns]

# %%
INPUT_TEXT = csv['text']

INPUT_TEXT
# Out:
# 0        Binay: Patuloy ang kahirapan dahil sa maling p...
# 1        SA GOBYERNONG TAPAT WELCOME SA BAGUO ANG LAHAT...
# 2        wait so ur telling me Let Leni Lead mo pero NY...
# 3         [USERNAME]wish this is just a nightmare that ...
# 4                     doc willie ong and isko sabunutan po
#                                ...
# 28456      Bisaya, Probinsyano/a, mostly Bisaya = katulong
# 28457    Amnesia. In my whole life wala pa ako nakasala...
# 28458    Kontrabida na ilang beses na tinalo at obvious...
# 28459    Yung antagonist laging kailangang sobrang sama...
# 28460    May nabaril or nasaksak na pero 'di pa tatawag...
# Name: text, Length: 28461, dtype: object

# %%
# Add unique word to set
UNIQUE_WORDS = set()

# Note: could probably stand to do more preprocessing
# there are a lot of unnecessary or duplicated words
# hence, a lot of noise
# so it makes sense to want to "clean" the text here

# Can make: remove punctuation, lowercase
for sample in INPUT_TEXT:
  for word in sample.split(' '):
    UNIQUE_WORDS.add(word)

# %%
UNIQUE_WORDS
# Out:
# {'',
#  'labag',
#  'leniLaban',
#  'flashmob',
#  'precinct,',
#  'witticism.',
#  'Practice',
#  'disasters',
#  'COLOR',
#  'haha..trending',
#  'umuusok',
#  'Roxas??',
#  'MAYBumoto',
#  'ka!Wala',
#  'sisimulan',
#  'Noooooooo...',
#  'bbm,',
#  'supportersnotomarcosduterte',
#  'Michelin',
#  'hindImahanap',
#  'jejemar',
#  'dug',
#  '"bobo',
#  'SKIPS',
#  'BEGGING',
#  'Tama.',
#  'kk',
#  'Kandidato(2016)',
#  'stvpid',
#  'donations,',
#  'nirerelate',
#  'MayThe',
#  'SASABHN',
#  'Dagdag/bawas',
#  'Kapikon',
#  'magdobidobidapdap',
#  'uuyuy',
#  'binabantayan',
#  'Tough',
#  'Blazing',
#  'BALA',
#  'mamemeke',
#  'time?',
#  'magpakailanman',
#  'Aboard',
#  'MATULOG',
#  'plausible',
#  'avibe',
#  'RIN.',
#  'Truuuuuuuuue',
#  'criticizes',
#  'weather!BaguioChel',
#  'Charet.',
#  'IPAGLABA',
#  'direct',
#  'Duterte.Logic',
#  'fastest',
#  'JoemsxczEXST',
#  'LeniREPORMAPara',
#  'Vice...',
#  'tanim-bala.',
#  'hadg',
#  'Lean',
#  'Edrian',
#  'P11B.',
#  'Sr.',
#  'Remind',
#  'Empower',
#  'KakampinkLet',
#  'geisha',
#  'Pambansang',
#  'adspremature',
#  'thinner',
#  'atlest',
#  'ROXASang',
#  'Libel',
#  'akosi',
#  'Iglesia',
#  'madePH',
#  'magrerebulusyon',
#  'gora',
#  'humiliating',
#  'SHT',
#  'preparations',
#  'ELCAC!',
#  'maiba',
#  'pinas.Kundi',
#  'Family.',
#  'loot:',
#  'napaka-informative.',
#  'againsa',
#  'korap?',
#  'ayusin',
#  'risks',
#  'blue?sorry',
#  'consumers',
#  "'spare",
#  'kagawad',
#  'ginegatekeep',
#  'termed.',
#  'epek',
#  'nanuhol',
#  'thoSMNIPresidential',
#  'isis',
#  'kasiiii',
#  'ofpeso',
#  'Tanggalin',
#  'LENIin',
#  'dagundong.',
#  'Naparami',
#  'UST:',
#  'volunteering',
#  'AMLC:',
#  'may-akda',
#  'engineers',
#  'IbotoDoc.Willie',
#  'Jrto',
#  'Hinirang!',
#  'Hotel626',
#  'pesos.',
#  'kindBBM',
#  'kickerdaily',
#  'KYO',
#  'BANSA',
#  'for[USERNAME]at',
#  'magbayad',
#  'Boba',
#  'call.',
#  'Ni-hindi',
#  'elephant',
#  'KARA',
#  'Burn',
#  'pia.',
#  'betrayed.',
#  'yorme.',
#  'Stan',
#  'PRIDEPRESERNIE',
#  'recordvia',
#  'k-pop.',
#  'Round-',
#  'bong',
#  'trial.sensa.health',
#  'bisyon',
#  'pretend',
#  'pinaglalabankakampink',
#  'kananaman',
#  'Kami',
#  'ROXAS??!!',
#  'kababaihan."',
#  'loveu',
#  'WIWWWWW',
#  'it!',
#  'travelling',
#  'namamalimos',
#  'expertise',
#  'Crap',
#  'Diyos!',
#  '.1K',
#  'monster',
#  'BAGUO',
#  'hackerskung',
#  '-No-El',
#  'MOOreKiligMoments',
#  'crafts',
#  'silbi',
#  'ga',
#  'Luis',
#  'Knockout',
#  'follower',
#  'masumo',
#  'WonderWoman',
#  'motibo',
#  'mahilig',
#  'pinupulot',
#  'yanhaha.',
#  'nagkampi',
#  'tao:',
#  'Economist',
#  'klase',
#  'senatoriables.',
#  'makapagpicture',
#  'SorsogonPINK',
#  'Missyou2',
#  '????????Dayaang',
#  'bow.',
#  'eager',
#  'MAMI',
#  'municipal',
#  'inspiration.',
#  'damned',
#  'ZubiagaPARTYLIST:',
#  'winskakasuhan',
#  'binabanatan.',
#  'prepared',
#  'MAIBIGAY',
#  'bhie',
#  'Relanes',
#  'Duwag.',
#  'pastress',
#  'akoLeni',
#  'magkaroon.',
#  'Winner',
#  'leaderleader?pasok',
#  'tayoAngat',
#  'Ngayun',
#  'binayroxaspoe.',
#  'nare-receive,',
#  'Tumutok',
#  'HAPPY',
#  'NGHalalan',
#  'makakatikim.Marcos',
#  'RE-POST:',
#  'alinlangan',
#  'eitherLeni',
#  'kakampinkhindi',
#  'others.\'"',
#  'Suho',
#  'VP.',
#  "LET'S",
#  '(adjective)',
#  'situations..',
#  'bringing',
#  'DECIDE',
#  'Juliana',
#  "originality.don't",
#  'magsaing?',
#  'galingmeron',
#  'Robledo',
#  'na!Hugs',
#  'WomanLet',
#  'naniniwalang',
#  'AngTweetNiBudz',
#  'von',
#  'Twicetagram',
#  'SASH???',
#  'fronds',
#  'Binaywag',
#  'sorry?',
#  'Katniel.',
#  'Roxasif',
#  'siya?',
#  'Damang',
#  'voteAngat',
#  'living',
#  'November.',
#  'bumilib',
#  'version.',
#  'DIKTADOR?',
#  'whove',
#  'maiinis',
#  'pinipili',
#  'twitter.com/xtian_mano/sta',
#  'cheatingthe',
#  'Gising!',
#  'photojournalists,',
#  'peoples',
#  'Pagkakatiwalaan',
#  'decencyi',
#  'HonHannah',
#  'nakomar',
#  '761+m',
#  'race',
#  'Lenilugaw',
#  'nowhis',
#  'Lucifer',
#  '(55',
#  'campsign',
#  'Korea',
#  'D:&lt;',
#  'magyayabang',
#  'kapwa?',
#  'oppressors',
#  'robbing.Halalan',
#  'PHCNNPresidential',
#  'similarity',
#  'Plant',
#  '"singapore"',
#  'TANGGAPIN',
#  'Pro-Binay',
#  'Sensa',
#  "What's",
#  'OVER!',
#  'mag-concede.',
#  'law..bakit',
#  'konteksto',
#  'bansa!Never',
#  'bya',
#  "Mother's",
#  'c_bibi',
#  'losestrategic',
#  's/p',
#  'sinseridad',
#  'masakit?',
#  'IRRESPONSIBLITY',
#  'kamatayan',
#  'Rachelle',
#  'HeheheKakampink',
#  'butch',
#  'pride',
#  'map',
#  'ng"Only',
#  'cases..',
#  'nag-iingay',
#  'MasipagLeni',
#  'hayst.',
#  'Vulnerable',
#  'Lacsonshady',
#  'tagaluto',
#  'politika!',
#  'survey!',
#  'Sabaysabay',
#  'Yehey',
#  'Halalan2022kasi',
#  'ryza',
#  'hers.',
#  'Ng',
#  'pinapakiusapan',
#  'calamansi',
#  'Napaka-complex',
#  'binubukambibig',
#  'clowns?',
#  'paraang',
#  'QUESTIONABLE',
#  'Hadoucaine',
#  'ganoon',
#  'timesNever',
#  'SEUNG',
#  'trolls!!!',
#  'kutsara',
#  'nakiki',
#  '[USERNAME]we',
#  'Ipagpatuloy',
#  'tungo',
#  'SAF44',
#  '"Tangna',
#  '25408391',
#  'forgotten',
#  'Em',
#  'buyag',
#  'Bahayihan',
#  '(such',
#  'Ibahin',
#  'Hangad',
#  'civilized',
#  'twt?s',
#  'pandemic-induced',
#  'none',
#  'Council',
#  'cancer(baka',
#  'rallying',
#  'Corykong',
#  'PhilippinesVote',
#  'tokneneng,',
#  'Connect',
#  'kanya..roxas',
#  "tv's",
#  'Bible!',
#  'Paghahanda',
#  'pilasee',
#  'JONAXXSTORIES',
#  'Kumustahan',
#  'Pakiuntog',
#  'EDIT:',
#  'LosariaKulay',
#  'u.NEVERAGAIN',
#  'cleanBring',
#  'unqualified',
#  'bloody',
#  'Fb',
#  'Philippinesat',
#  "Uniteam's",
#  'Lolong',
#  'LB',
#  '|Comelec',
#  'Negro."',
#  'Phl',
#  'SIMONPAMPANGA',
#  'dswp.pero',
#  'prospect',
#  'truth!Marcos',
#  'kasipag',
#  'friends',
#  'OP,',
#  'Itodo',
#  'Binaynakakainis',
#  'kilala',
#  'ibukas',
#  'ikasal?',
#  'makipagtalo',
#  'OKEY',
#  'MAG-ARAL',
#  'Appreciate',
#  'n-slur',
#  'Pwe',
#  'hihiIpana10',
#  'kagusto',
#  'props',
#  'critic',
#  'magpapahinga',
#  'hi',
#  'dyan.',
#  'Awards.',
#  'e.E',
#  'cute',
#  'Mondays',
#  'Courage',
#  '008',
#  'figures?',
#  'Miyerkules',
#  'ka[USERNAME]kasi',
#  'gisend',
#  'Dindo',
#  'buti',
#  'allMar',
#  'talagang',
#  'moreThanks',
#  'mapababae',
#  'Ops!',
#  'Warfreak',
#  'VP[USERNAME]at',
#  'awayin',
#  'Debate????',
#  'Nahiya',
#  'binay..pra',
#  'mktg',
#  'Makiisa',
#  'multistan',
#  'toll',
#  'resources',
#  'Dutertards!',
#  'nakakasama',
#  'yun??',
#  'NGANGA',
#  'ha?Kaya',
#  'Binaywhy',
#  'Binaymay',
#  'wowsupporting',
#  'before..if',
#  'Humurit',
#  'i-mute',
#  'Debates2016',
#  'DoH',
#  'Kakairita',
#  'CASES',
#  'PHarena',
#  'cites',
#  'anlayo',
#  'makisama',
#  'BINAY:Did',
#  'PINAS',
#  'lab',
#  'kakadikit',
#  'makamit',
#  'adopts',
#  'realistic.',
#  'QueenVPLeni',
#  'PUTIK',
#  'hanapin',
#  'PAKITANG',
#  'Swab',
#  'perspective',
#  'ai',
#  'regime',
#  'Sunod',
#  'Purple',
#  '[USERNAME]"The',
#  'Binaysinungaling.',
#  'wanag',
#  'Millenial',
#  'iaassist',
#  'grabeng',
#  'Dept.',
#  'LiwanagSaDilim',
#  'Dept',
#  'ahahaah',
#  'Agadan',
#  'roxas??????Tangina',
#  'working',
#  'P*****',
#  'Nortekahit',
#  'maka-Binaypero',
#  'mundoAngat',
#  'Pinoy?',
#  'ken.',
#  'Thatsmy',
#  'Run',
#  'zoomicron',
#  'cubicle',
#  'hingian.',
#  'Notebook',
#  'NAPAKARAMI',
#  'Syempredirty',
#  'Roxas?eto',
#  'puesto',
#  'Leodegario',
#  'kadesperado?',
#  'doctor',
#  'Batak',
#  'thisAnong',
#  'nasakbayan.',
#  'ntl',
#  'York',
#  'Kae',
#  'bato',
#  'nag-agree',
#  'cagey',
#  'stamp.',
#  'umaga,',
#  'tumae',
#  'ehe!',
#  '[USERNAME]alumnus',
#  'Lights',
#  'Tagalinis',
#  'humusga',
#  'Led',
#  'Umiinit',
#  'UniverseMargie',
#  'many."',
#  'pag-usapan',
#  'Hontiveros',
#  'na"??',
#  'MDAMakati',
#  'Machiavellian',
#  'helpSalamat',
#  'winnerPick',
#  'BBMPara',
#  'nivp',
#  'unfinished',
#  'bagsak',
#  'planeta',
#  'January',
#  'nonsense.',
#  'MagnanakawCarlos',
#  'Sir!',
#  'nakalaban',
#  'BEH',
#  '2015/10/9',
#  'dami!last',
#  'nognogwag',
#  'how[USERNAME]topped',
#  'Guinayangan.',
#  'declares',
#  'scenario,',
#  'Naaano',
#  'MBCDialogues.',
#  'four',
#  'magdecide!',
#  'nababahala.',
#  'GuzmanKBP',
#  'TRIGGER',
#  'competent',
#  'sleepVote',
#  'Good?!',
#  'makuntento',
#  'kinawat',
#  'Nalalapit',
#  'katuturan?',
#  'Nasagot',
#  '(willie',
#  'riza..',
#  'AmithsOdaur',
#  'imperialist',
#  'Lawjusqq',
#  'pagbigay',
#  'SEN.',
#  'Tangina,',
#  'imagine.',
#  'nakikinabang',
#  'jay',
#  'Sino???"',
#  'Raphael',
#  'KILALA',
#  'pagkapangulo.',
#  'aromatic?',
#  'me??!!',
#  'sisimutin',
#  'JrBBM',
#  'Elmer',
#  'Commercial:',
#  'WhosPhilippines',
#  'COMELECLet',
#  'GeronaPag',
#  'thefutureisfemale',
#  '"galit',
#  'believers',
#  'ni-isa',
#  'puntosana',
#  'daw!',
#  'Allies',
#  'na-carried',
#  'Heto',
#  'constitutions..pls',
#  'Sunday:Walden',
#  'crisp',
#  'tiwaling',
#  'COMELEC.',
#  'magturo',
#  'lumutang',
#  'nognogminion',
#  'berde',
#  'driver',
#  're-staging',
#  'kakautal',
#  'oyy',
#  'Adik',
#  'Gonzales).',
#  'SSUES',
#  'leni...',
#  'SASAMPALIN',
#  'pinasHalalan',
#  'BULGAR!',
#  'lalamunan',
#  "Scout's",
#  'win."',
#  'ULUL.',
#  'Laptrip',
#  'EXO-L',
#  'Usually',
#  'mag-absent',
#  'pagkilala',
#  'spirit!!Victory',
#  'lahat!!!!',
#  'magbukas',
#  'baril',
#  'tawad',
#  'pagsigaw',
#  'aman',
#  'skin??',
#  '24/7',
#  'katagalan.',
#  'taxwhich',
#  'makontento',
#  'hahahahahahaha',
#  'play',
#  'minamahal',
#  'sagot.Mad',
#  'LIVES',
#  'Maglokohan',
#  'childrens',
#  'sabdraws',
#  'dimwits',
#  'anyof[USERNAME]business!',
#  'GANITOSIGURO',
#  'viewsSMNIPresidential',
#  'SUBSTTUTE...heheheh',
#  'news!!!',
#  'bordering',
#  'obvious?',
#  'onlybinay',
#  '243',
#  'alarming[USERNAME]',
#  'salon',
#  'us?Kay',
#  'EH"',
#  'KINGINA!!!!',
#  'picturesAng',
#  'machine)',
#  'Cebufor',
#  'cos',
#  'kayo.',
#  'ago',
#  'Charlie',
#  'neck',
#  'natiin',
#  'conflicts',
#  'Hahahard',
#  'politics....',
#  'fitted',
#  'cameras',
#  'natinto!',
#  'Playboy',
#  'pakeke-alam',
#  'bayag',
#  'debate.Halalan',
#  'Para-paraan',
#  'tayo',
#  'REALTALK',
#  'nina[USERNAME]ito',
#  'Limlingan',
#  'thrid',
#  'goodddd!',
#  'KELAN',
#  'reason.',
#  'traffic',
#  'bijo?',
#  'Maria.',
#  'riot',
#  'sufficiency',
#  'nakakarating',
#  'namatay',
#  'pekeng',
#  'countrys',
#  'Txt',
#  'Langitisinantabi',
#  'judgemental',
#  'here.',
#  'lion?',
#  'favored',
#  'STATSDont',
#  'Presidentbut',
#  'tvc!',
#  'card!',
#  'enlightened',
#  'Paspecial',
#  'pa.Baka',
#  'CLAUDIA.',
#  '??!!??!',
#  'nagkakabit',
#  'guilt-trip',
#  'scions.',
#  'lingers.',
#  'blocLetsjust',
#  'futures',
#  'Miriam-Leni.',
#  'masugid',
#  'Hokage',
#  'gubat',
#  'Gagong',
#  '"Cookfest"',
#  '#NAME?',
#  'toMARroxas',
#  'kulang.',
#  'onionsHalalan',
#  'MANOBONgayong',
#  'Kahiya.',
#  'Marpaannounce',
#  '"I"?',
#  'Jeff',
#  'nag-hold',
#  'mangagawa',
#  'Putapeteng',
#  'mamanahin',
#  'Reyes)',
#  'more!!',
#  'IskoBughaw',
#  'Politician',
#  'jp',
#  'YASSSS',
#  'Feb.',
#  'Like:',
#  'you[USERNAME]and[USERNAME]',
#  'naa.',
#  'MONTEMAYOR!!!',
#  'Binay"....yan',
#  'incident',
#  'Ilongo.CAPIZ',
#  'good',
#  'mapipigilan',
#  'BastaBBM',
#  'Apr',
#  'v*)',
#  "WellDuterte's",
#  'kakampeste',
#  'Eterno',
#  'causa',
#  'RobredoKakampinkLeni',
#  'malisyosong',
#  'kakamp',
#  '"K"',
#  'theanchor/producer[USERNAME]',
#  'journalism',
#  'sad.??',
#  'NancyNOGNOGsi',
#  'manggamit',
#  'clutch',
#  '"employee',
#  'collectively',
#  'UUNLAD',
#  'magreresign',
#  'roxas...tignan',
#  'diskartepuro',
#  'Nog.',
#  'concededmay',
#  'faith-based',
#  'news',
#  'nabibilaran',
#  'yanNo',
#  'parents',
#  'Belated',
#  'bauan',
#  'PANDARAYA',
#  'Sha)...',
#  'Tomas',
#  'nitoIpana7o',
#  'Romero',
#  'nyaHAHAHA!na',
#  'FED',
#  '(Photo:CTO)',
#  'DudirtyRappler',
#  'yanLeni',
#  'think?BBM',
#  'Heart',
#  'onlights',
#  'Talks',
#  'nagreact',
#  'Pagka-Pangulo',
#  'prior',
#  'Balikatan',
#  'GAH',
#  'no?Araw',
#  'NANALOALIS',
#  'river',
#  'prospects',
#  'resulting',
#  'KAYA!',
#  'DuterteRappler',
#  'cohorts',
#  'akoNutribun',
#  "Jr's",
#  '(Nov.',
#  'Ekis',
#  'revilla',
#  'Indi',
#  'Marnakikiparehas',
#  'SiMP-',
#  'tatahol',
#  'Babae',
#  'exhawsted',
#  'paves',
#  'Deym!?',
#  '(Official',
#  'l0ckd0wn',
#  'Pabayaan',
#  "ma'am",
#  'curtail',
#  'Ewww!',
#  'PadillaKakampink',
#  'react!',
#  'override',
#  'words...',
#  'yun!!',
#  'koang',
#  '$.3M',
#  'SERIOUS!',
#  'Ayun!!Leni',
#  'chaka',
#  'revolutionary',
#  'tinatakbuhan?',
#  'Ochabillo',
#  'P1ng',
#  'Gloria',
#  'ROXAS?',
#  'EVERYONE',
#  'Napakarami',
#  'Maam[USERNAME]',
#  'dweeb.',
#  'Francisco',
#  'magpaDQ',
#  '"Nigger"',
#  'mdsbut',
#  'today.Lau',
#  'ikaw.',
#  'Sophie',
#  'Probinsyano/a,',
#  'pansinin.',
#  'literal',
#  'animal.',
#  'Elec',
#  'citizenship.',
#  'gg',
#  'Coke',
#  'owning',
#  'accepting',
#  'officeDikay',
#  'BINAYarang',
#  'WISELYYEARS',
#  'Mamaya.',
#  'PH[USERNAME]',
#  'Alejandria',
#  'Employees',
#  'Claude',
#  'nagtatanga',
#  'this.Eleksyon',
#  'Track',
#  'ngarag',
#  'abakit',
#  'awkward.',
#  'Bankersfor',
#  'sincerely',
#  'tlgamukha',
#  'Binaynkakairita',
#  'rp',
#  'Binaynakakatakot!',
#  'NEG',
#  'magdodouble',
#  'kanda-utal',
#  'Ka-boses',
#  'Tapat!',
#  'involved.',
#  'rediscover',
#  'stickerUy',
#  'Virgin',
#  'sinangag.',
#  'RADIO!!',
#  'pinamimihasa',
#  'Dyan',
#  'nation!God',
#  'conditioning!',
#  'napictureanmeron',
#  'SecGuerilla',
#  'nagdrive',
#  'X[USERNAME]',
#  'mv',
#  'sinuportahang',
#  'MAHALN',
#  'hinayaan',
#  'plastik',
#  'censored',
#  'Toti',
#  'mitigate',
#  'siya.Pero',
#  'paki-apply',
#  'Tapusin',
#  'slate',
#  '*chura',
#  'MASAHOL',
#  '"matalino',
#  'Poehandang',
#  'NAKAW.Grabe',
#  'MAMAYA',
#  'ngI',
#  'puta.',
#  'aabsent',
#  'ALDUBMissing',
#  'area?',
#  'P.S',
#  'ahikaw',
#  'vivi',
#  'Nuevo',
#  '|...',
#  'panggamit',
#  'inencourage',
#  'manay',
#  'aruga',
#  'Are',
#  'sector',
#  'dibale',
#  'kampi-kampihan',
#  'mind.GPOE',
#  'FilipinosWe',
#  'duterteVP',
#  'Liza',
#  'TRAPOS',
#  'Danvi',
#  'event.',
#  'susunod',
#  'ANO',
#  'siniraan',
#  'dahil[USERNAME]',
#  'middle',
#  'PresidentRappler',
#  'ABS-CBN',
#  'aspeto',
#  'day...',
#  'ipaintindi',
#  'consent',
#  'AprilLeody',
#  'PGTDebate',
#  'BinayMar.',
#  'complacent.What',
#  'Roxasboooo',
#  'Hahahaha.',
#  'Mariiwan',
#  'kuryente.Kaya',
#  'ALBAAnd',
#  'tumagal',
#  'grabe.',
#  '782',
#  'utas',
#  'paat',
#  'kao',
#  'FUCK.',
#  'H',
#  'Bulakenya',
#  'Ka-daming',
#  'Natataranta',
#  'WayMiting',
#  'INFORMATION',
#  'nakasayaw',
#  'Yasss',
#  'probs',
#  'MAGKAISA',
#  'nangalabit!!!',
#  'Threat',
#  'RobredoPing',
#  'posts..',
#  'Manrique',
#  'dumaang',
#  'impaired',
#  'Darna',
#  'Chair',
#  'Eto',
#  'CubaoQuezon',
#  "'American",
#  'ibaKasamamo',
#  'st',
#  'staged',
#  'Kala',
#  'tanga',
#  'LET',
#  ...}

# %%
len(UNIQUE_WORDS)
# Out:
# 76871

# %%
# Make our dictionaries
WORD_TO_INDEX = {}
INDEX_TO_WORD = {}

for index, word in enumerate(sorted(list(UNIQUE_WORDS))):
  WORD_TO_INDEX[word] = index
  INDEX_TO_WORD[index] = word

# %%
WORD_TO_INDEX
# Out:
# {'': 0,
#  '\n\nCNN': 1,
#  '\n\nDuterte': 2,
#  '\n\nKita': 3,
#  '\n\nMAGLABAS': 4,
#  '\n\nUlul\nDouble\nStandard': 5,
#  '\n\ntangina': 6,
#  '\n\nthis': 7,
#  '\n\ntw': 8,
#  '\n[USERNAME]\n': 9,
#  '!': 10,
#  '!!': 11,
#  '!!!': 12,
#  '!!!!': 13,
#  '!!!!!': 14,
#  '!!!!!!': 15,
#  '!!!!!!!!': 16,
#  '!!!!!!!!!!!': 17,
#  '!!!!Iboboto': 18,
#  '!!!!Ipanalo': 19,
#  '!!!Leni': 20,
#  '!!!Thank': 21,
#  '!!![USERNAME]': 22,
#  '!!!made': 23,
#  '!!!think': 24,
#  '!!...': 25,
#  '!!EDSA': 26,
#  '!!Gagawa': 27,
#  '!!InshaAllah': 28,
#  '!!Leni': 29,
#  '!!ROBREDO': 30,
#  '!!Thank': 31,
#  '!!anak': 32,
#  '!"': 33,
#  '!.': 34,
#  '!?': 35,
#  '!????': 36,
#  '!Araw': 37,
#  '!BBM': 38,
#  '!DI': 39,
#  '!Ipanlo': 40,
#  '!Kulay': 41,
#  '!Layout': 42,
#  '!Leni': 43,
#  '!Let': 44,
#  '!Neri': 45,
#  '!Non': 46,
#  '!PRAY': 47,
#  '!Pampanga': 48,
#  '!Panaloang': 49,
#  '!Pero': 50,
#  '!Youth': 51,
#  '![USERNAME]': 52,
#  '!artph': 53,
#  '!kakampink': 54,
#  '!love': 55,
#  '!sko': 56,
#  '!via[USERNAME]': 57,
#  '"': 58,
#  '""Andy': 59,
#  '""Tito""': 60,
#  '"%': 61,
#  '"(Photo': 62,
#  '"-': 63,
#  '"..': 64,
#  '"...Binay:': 65,
#  '"0.004%"': 66,
#  '"250000': 67,
#  '"2nd': 68,
#  '"3%"': 69,
#  '"A': 70,
#  '"AKO': 71,
#  '"ANO': 72,
#  '"AQUINO': 73,
#  '"Abnoy': 74,
#  '"According': 75,
#  '"Actually': 76,
#  '"Ah': 77,
#  '"Akin': 78,
#  '"Ako': 79,
#  '"Alam': 80,
#  '"All': 81,
#  '"Am-Girl"': 82,
#  '"American': 83,
#  '"And': 84,
#  '"Andami': 85,
#  '"Ang': 86,
#  '"AngatBuhayLahat': 87,
#  '"Ano': 88,
#  '"Anong': 89,
#  '"Anubayan': 90,
#  '"Anytime': 91,
#  '"Asia\'s': 92,
#  '"Asked': 93,
#  '"At': 94,
#  '"Ate,': 95,
#  '"Auto': 96,
#  '"Ay': 97,
#  '"Ayaw': 98,
#  '"Ayoko': 99,
#  '"Ayusin': 100,
#  '"BA\'T': 101,
#  '"BAHALA': 102,
#  '"BAYAN': 103,
#  '"BBM': 104,
#  '"BE': 105,
#  '"BEBE': 106,
#  '"BINAY': 107,
#  '"BINAYIKAW': 108,
#  '"BLACK"': 109,
#  '"BUB"': 110,
#  '"Badjao"s': 111,
#  '"Bahala': 112,
#  '"Bakit': 113,
#  '"Baw': 114,
#  '"Bayan': 115,
#  '"Bayot"': 116,
#  '"Beatles': 117,
#  '"Beauty': 118,
#  '"Because': 119,
#  '"Besidessuch': 120,
#  '"Best': 121,
#  '"Between': 122,
#  '"Bi-Chiz"': 123,
#  '"Bilang': 124,
#  '"Binay': 125,
#  '"Binay"': 126,
#  '"Binay:': 127,
#  '"Binayhe': 128,
#  '"Birds': 129,
#  '"Black': 130,
#  '"Bobo': 131,
#  '"Bongbong"': 132,
#  '"Boy': 133,
#  '"Bring': 134,
#  '"Buksan': 135,
#  '"But': 136,
#  '"CNN': 137,
#  '"Cars': 138,
#  '"Condolence': 139,
#  '"Cookfest"': 140,
#  '"Corrupt"': 141,
#  '"Courtesy': 142,
#  '"DAHIL': 143,
#  '"DIGOY"': 144,
#  '"DITO': 145,
#  '"DOC"': 146,
#  '"DON\'T': 147,
#  '"DUTERTE"': 148,
#  '"Daang': 149,
#  '"Dahil': 150,
#  '"Daniel': 151,
#  '"Dapat': 152,
#  '"Darker': 153,
#  '"De': 154,
#  '"Decent"?': 155,
#  '"Describe': 156,
#  '"Desperate': 157,
#  '"Di': 158,
#  '"Did': 159,
#  '"Digong"': 160,
#  '"Dilawan"': 161,
#  '"Dinaya': 162,
#  '"Disqualify': 163,
#  '"Do': 164,
#  '"Doc': 165,
#  '"Doc"': 166,
#  '"Don\'t': 167,
#  '"Doon': 168,
#  '"Dumb': 169,
#  '"Duterte': 170,
#  '"Duterte"': 171,
#  '"Duterte\'s': 172,
#  '"Dutertedumarami': 173,
#  '"EMERGENCY:': 174,
#  '"EXCEPT': 175,
#  '"Economist': 176,
#  '"Edi': 177,
#  '"Even': 178,
#  '"Everybody\'s': 179,
#  '"Fake': 180,
#  '"Fast': 181,
#  '"Former': 182,
#  '"Formula': 183,
#  '"From': 184,
#  '"GOOD': 185,
#  '"Gagi': 186,
#  '"Ganito': 187,
#  '"Gapangan"': 188,
#  '"Gendeng': 189,
#  '"Gentle': 190,
#  '"Gobyernong': 191,
#  '"God-fearing"': 192,
#  '"Good': 193,
#  '"Grabe': 194,
#  '"Grace': 195,
#  '"Gracemag-usap': 196,
#  '"Greed."': 197,
#  '"Greediest': 198,
#  '"Guys': 199,
#  '"Guyswag': 200,
#  '"HAPPY': 201,
#  '"HINDI': 202,
#  '"HUMILITY"': 203,
#  '"Ha?"': 204,
#  '"Hala': 205,
#  '"Have': 206,
#  '"He': 207,
#  '"He\'s': 208,
#  '"HelloGuanzi?"': 209,
#  '"Help': 210,
#  '"Hi': 211,
#  '"Higit': 212,
#  '"Hiling".': 213,
#  '"Hindi': 214,
#  '"Hocus': 215,
#  '"Hoe': 216,
#  '"How': 217,
#  '"Hoy': 218,
#  '"I': 219,
#  '"I""I': 220,
#  '"I"?': 221,
#  '"I\'m': 222,
#  '"IN': 223,
#  '"IPAGPAPATULOY': 224,
#  '"IPANALO': 225,
#  '"ISANG': 226,
#  '"Iboboto': 227,
#  '"Iboto': 228,
#  '"If': 229,
#  '"Ika': 230,
#  '"Ikaw': 231,
#  '"Ilokano': 232,
#  '"Im': 233,
#  '"Imperial': 234,
#  '"Integrity': 235,
#  '"Ipagpapatuloy': 236,
#  '"Ipanalo': 237,
#  '"Is': 238,
#  '"Isang': 239,
#  '"Isigaw': 240,
#  '"Isko': 241,
#  '"It': 242,
#  '"Ito': 243,
#  '"Joey"': 244,
#  '"Jusq': 245,
#  '"Just': 246,
#  '"K"': 247,
#  '"KABATAAN': 248,
#  '"KAMPANYA': 249,
#  '"KATHNIEL"': 250,
#  '"Kahirapan': 251,
#  '"Kahit': 252,
#  '"Kailangan': 253,
#  '"Kala': 254,
#  '"Katulad': 255,
#  '"Kay': 256,
#  '"Kaya': 257,
#  '"Kids': 258,
#  '"Kiko"': 259,
#  '"Kilala': 260,
#  '"Killer"DuterteGrace': 261,
#  '"Kinokondena': 262,
#  '"Kita': 263,
#  '"Know': 264,
#  '"Kris': 265,
#  '"Kung': 266,
#  '"Kuno"': 267,
#  '"Kuya': 268,
#  '"LEN': 269,
#  '"LIBRE': 270,
#  '"LOOSER!!"': 271,
#  '"LOVE': 272,
#  '"Laban': 273,
#  '"Labas': 274,
#  '"Laging': 275,
#  '"Laki': 276,
#  '"Leche': 277,
#  '"Leni': 278,
#  '"Leni"': 279,
#  '"Let': 280,
#  '"Libreng': 281,
#  '"Lito': 282,
#  '"Lito"': 283,
#  '"Lonely': 284,
#  '"Look': 285,
#  '"Loveli-Ness"': 286,
#  '"Loyalty"': 287,
#  '"MAGNANAKAW"': 288,
#  '"MANANALO': 289,
#  '"MAR': 290,
#  '"MAY': 291,
#  '"Ma\'am/lola,': 292,
#  '"Madaming': 293,
#  '"Mag': 294,
#  '"Maganda': 295,
#  '"Magbubungaan"': 296,
#  '"Magkaisa"': 297,
#  '"Maglaba': 298,
#  '"Magsasapakan': 299,
#  '"Mahal': 300,
#  '"Makapoy': 301,
#  '"Makati': 302,
#  '"Mananalo': 303,
#  '"Manchurian': 304,
#  '"Manny"': 305,
#  '"Mar': 306,
#  '"Marami': 307,
#  '"Marco"': 308,
#  '"Marcos': 309,
#  '"Marites"': 310,
#  '"Martial': 311,
#  '"Maruhas"': 312,
#  '"Marunong': 313,
#  '"Masyadong': 314,
#  '"Matagal': 315,
#  '"May': 316,
#  '"Maynila"?': 317,
#  '"Meron': 318,
#  '"Mga': 319,
#  '"Micronutrient': 320,
#  '"Miriam': 321,
#  '"Money': 322,
#  '"Move': 323,
#  '"Mr.': 324,
#  '"Muslim"': 325,
#  '"N': 326,
#  '"NAGAWA"': 327,
#  '"NAGBROWNOUT': 328,
#  '"NANAY"': 329,
#  '"NO': 330,
#  '"NO"': 331,
#  '"NOGNOG"': 332,
#  '"NaMarcos': 333,
#  '"Nagawa': 334,
#  '"Nagnakaw': 335,
#  '"Nagpakamatay': 336,
#  '"Nagpapansin"': 337,
#  '"Nakakaoffend': 338,
#  '"Nalulungkot': 339,
#  '"Nandito': 340,
#  '"Napakaraming': 341,
#  '"Nasan': 342,
#  '"Natutulog': 343,
#  '"Nemo': 344,
#  '"Nese': 345,
#  '"Next': 346,
#  '"Ngayon': 347,
#  '"Nigger"': 348,
#  '"No': 349,
#  '"No.': 350,
#  '"Nog': 351,
#  '"Nog-nog"wag': 352,
#  '"Nog-nogpandaklaki': 353,
#  '"Nognog': 354,
#  '"Nognog"': 355,
#  '"Nognog.': 356,
#  '"Nognog/pandak"': 357,
#  '"NognogPandak"': 358,
#  '"NognogPandakLaki': 359,
#  '"Nognogpandak\'yan': 360,
#  '"Nognogpandakat': 361,
#  '"Nognogpandaklaki': 362,
#  '"Nognogpandakpero': 363,
#  '"Not': 364,
#  '"OLNY': 365,
#  '"ONLY': 366,
#  '"Oayan': 367,
#  '"Okay': 368,
#  '"Omg': 369,
#  '"Only': 370,
#  '"Oo': 371,
#  '"Oops...': 372,
#  '"Ovaltine"': 373,
#  '"PANDAK"?': 374,
#  '"PARATING': 375,
#  '"POEPutangina': 376,
#  '"PROTECT': 377,
#  '"PROVE': 378,
#  '"PUTANGINA': 379,
#  '"Paano': 380,
#  '"Pag': 381,
#  '"Pag"': 382,
#  '"Pagbubuo': 383,
#  '"Pagmamahal': 384,
#  '"Panama"': 385,
#  '"Pandak': 386,
#  '"Pandak"': 387,
#  '"Panday"': 388,
#  '"Pang': 389,
#  '"Pangit"': 390,
#  '"Parot': 391,
#  '"Pasalubong"': 392,
#  '"Patay': 393,
#  '"Patayin': 394,
#  '"Paulit-ulit': 395,
#  '"Penalty': 396,
#  '"Perception': 397,
#  '"Pero': 398,
#  '"Pet': 399,
#  '"PiliBinay"': 400,
#  '"Pinansin': 401,
#  '"Pinasyal': 402,
#  '"Ping"': 403,
#  '"Pink': 404,
#  '"Pre': 405,
#  '"Presidential': 406,
#  '"Pride"': 407,
#  '"Problema': 408,
#  '"Putangina': 409,
#  '"RT': 410,
#  '"Ready': 411,
#  '"Respect': 412,
#  '"Ripley\'s': 413,
#  '"Robredonaglabas': 414,
#  '"Rodrigo': 415,
#  '"Rosas"': 416,
#  '"Roxas': 417,
#  '"Roxas:': 418,
#  '"Roxasumikot': 419,
#  '"SA': 420,
#  '"SD"': 421,
#  '"SHE': 422,
#  '"SHUT': 423,
#  '"SI': 424,
#  '"SMNI': 425,
#  '"SMNIpresidentialdebatenorbertogonzales': 426,
#  '"Sa': 427,
#  '"Sakit"': 428,
#  '"Salamat': 429,
#  '"Sama-sama': 430,
#  '"Same-sex': 431,
#  '"Seeing': 432,
#  '"Sen.': 433,
#  '"Shut': 434,
#  '"Si': 435,
#  '"Sick': 436,
#  '"Simpleng': 437,
#  '"SinOng': 438,
#  '"Sino': 439,
#  '"Sinong': 440,
#  '"Sirano': 441,
#  '"Sonny"': 442,
#  '"Sorry': 443,
#  '"Special': 444,
#  '"Stealing': 445,
#  '"Susmaryosep"': 446,
#  '"TANGA': 447,
#  '"TITO"': 448,
#  '"Tama': 449,
#  '"Tangna': 450,
#  '"Tapatin': 451,
#  '"Tatanggalin': 452,
#  '"Teacher': 453,
#  '"Thank': 454,
#  '"The': 455,
#  '"There': 456,
#  '"There\'s': 457,
#  '"They\'re': 458,
#  '"This': 459,
#  '"Tignan': 460,
#  '"Tito"': 461,
#  '"Tito""': 462,
#  '"To': 463,
#  '"Today': 464,
#  '"Totoo': 465,
#  '"Touch': 466,
#  '"Tumatakbo': 467,
#  '"U"': 468,
#  '"ULING': 469,
#  '"UNITY"': 470,
#  '"UNSTABLE': 471,
#  '"Uling': 472,
#  '"Unity"': 473,
#  '"Unlike': 474,
#  '"Uyy!': 475,
#  '"VP': 476,
#  '"Vice': 477,
#  '"Vicente': 478,
#  '"Victory': 479,
#  '"WAG': 480,
#  '"WALA': 481,
#  '"WALANG': 482,
#  '"Wag': 483,
#  '"Wait': 484,
#  '"Wala': 485,
#  '"Walang': 486,
#  '"We': 487,
#  '"What': 488,
#  '"Who': 489,
#  '"Why': 490,
#  '"Why?': 491,
#  '"YES': 492,
#  '"Yan': 493,
#  '"Yes': 494,
#  '"YesI': 495,
#  '"Yesof': 496,
#  '"You': 497,
#  '"You\'re': 498,
#  '"Your': 499,
#  '"Yung': 500,
#  '"[USERNAME]:': 501,
#  '"[USERNAME]:??': 502,
#  '"accomplishments".': 503,
#  '"according': 504,
#  '"achievement"': 505,
#  '"achievements"': 506,
#  '"after': 507,
#  '"akala': 508,
#  '"ako': 509,
#  '"alam': 510,
#  '"all': 511,
#  '"allies"': 512,
#  '"among': 513,
#  '"anak': 514,
#  '"analysis"': 515,
#  '"analyze"': 516,
#  '"ang': 517,
#  '"anti-war': 518,
#  '"auntie"': 519,
#  '"ay': 520,
#  '"bagito"': 521,
#  '"baka': 522,
#  '"bakit': 523,
#  '"bakit?"': 524,
#  '"bato-bato': 525,
#  '"because': 526,
#  '"benefits"': 527,
#  '"bias"': 528,
#  '"biased"?': 529,
#  '"bilang': 530,
#  '"binayaran"': 531,
#  '"bobo': 532,
#  '"bobo"': 533,
#  '"borrowings"': 534,
#  '"bridge"': 535,
#  '"budget': 536,
#  '"call': 537,
#  '"calling': 538,
#  '"cannot': 539,
#  '"climate': 540,
#  '"competence': 541,
#  '"conceive"': 542,
#  '"connections"': 543,
#  '"convenience': 544,
#  '"convicted"': 545,
#  '"corrupt"?Wanted': 546,
#  '"corrupt?"': 547,
#  '"daang': 548,
#  '"dahil': 549,
#  '"daw"': 550,
#  '"daya"': 551,
#  '"debate"': 552,
#  '"decent"': 553,
#  '"degrees"': 554,
#  '"desente"': 555,
#  '"desperado"': 556,
#  '"di': 557,
#  '"dinamay".': 558,
#  '"dinaya"': 559,
#  '"disappeared"': 560,
#  '"diskarte"': 561,
#  '"do': 562,
#  '"don\'t': 563,
#  '"dutertards"': 564,
#  '"easy': 565,
#  '"emergency': 566,
#  '"emergency"': 567,
#  '"employee': 568,
#  '"enhypen': 569,
#  '"entertainment': 570,
#  '"envelopes""incentives"etc...': 571,
#  '"errthang"binay': 572,
#  '"flavor': 573,
#  '"for': 574,
#  '"free': 575,
#  '"friends"': 576,
#  '"galing"': 577,
#  '"galit': 578,
#  '"ganito': 579,
#  '"golden': 580,
#  '"graduate': 581,
#  '"great': 582,
#  '"great"': 583,
#  '"gusto': 584,
#  '"gutom"!': 585,
#  '"ha"': 586,
#  '"habang': 587,
#  '"hakot': 588,
#  '"hala': 589,
#  '"halika': 590,
#  '"hanggang': 591,
#  '"have': 592,
#  '"heartbreaking"': 593,
#  '"here': 594,
#  '"hideout"': 595,
#  '"hijack': 596,
#  '"hindi': 597,
#  '"honesty': 598,
#  '"household': 599,
#  '"how': 600,
#  '"hugot"': 601,
#  '"humbled"': 602,
#  '"humming': 603,
#  '"huy': 604,
#  '"i': 605,
#  '"idols"': 606,
#  '"if': 607,
#  '"in': 608,
#  '"indecisive".': 609,
#  '"independent': 610,
#  '"interesting"': 611,
#  '"interviews"': 612,
#  '"investment"': 613,
#  '"irrelevant"': 614,
#  '"it': 615,
#  '"itim"': 616,
#  '"job': 617,
#  '"joking"': 618,
#  '"jun': 619,
#  '"kahit': 620,
#  '"kakampink"': 621,
#  '"kami': 622,
#  '"kamote"': 623,
#  '"kana"chix': 624,
#  '"kasalanan': 625,
#  '"kase': 626,
#  '"katulad': 627,
#  '"kaya': 628,
#  '"kinain': 629,
#  '"kokey"': 630,
#  '"komunista"': 631,
#  '"korupsyon': 632,
#  '"kulelat"': 633,
#  '"kung': 634,
#  '"kurakot."': 635,
#  '"kyah': 636,
#  '"lahat': 637,
#  '"lahat"': 638,
#  '"laki': 639,
#  '"lawless"': 640,
#  '"lazy""teka-teka"': 641,
#  '"legislation"': 642,
#  '"liars': 643,
#  '"lies': 644,
#  '"lies"': 645,
#  '"lonely': 646,
#  '"loot"': 647,
#  '"lutang"': 648,
#  '"lutang"Marcos': 649,
#  '"m....m...mi-....matuwid': 650,
#  '"m4R': 651,
#  '"mabuti': 652,
#  '"magaling': 653,
#  '"magikero."': 654,
#  '"magkaiba': 655,
#  '"magnanakaw"': 656,
#  '"magnanakaw".': 657,
#  '"mahabag"': 658,
#  '"mahirap': 659,
#  '"maitim"': 660,
#  '"make': 661,
#  '"mamamatay': 662,
#  '"mamaya': 663,
#  '"mangita': 664,
#  '"mar': 665,
#  '"marriage': 666,
#  '"marwhat': 667,
#  '"mas': 668,
#  '"matalino': 669,
#  '"may': 670,
#  '"meryenda': 671,
#  '"messiahs"': 672,
#  '"mind".': 673,
#  '"misstep"': 674,
#  '"moneyed"': 675,
#  '"more': 676,
#  '"most': 677,
#  '"murit': 678,
#  '"my': 679,
#  '"nababad': 680,
#  '"nakakatakot"': 681,
#  '"nanalo"': 682,
#  '"nang".': 683,
#  '"nasanay': 684,
#  '"natalo': 685,
#  '"need': 686,
#  '"neutral"': 687,
#  '"news"': 688,
#  '"ng"': 689,
#  '"no': 690,
#  '"nog': 691,
#  '"nog-nog"': 692,
#  '"nognog': 693,
#  '"nognog"': 694,
#  '"nognog".': 695,
#  '"nognogpandakkurakot"': 696,
#  '"nognogpandaklaki': 697,
#  '"nonogpandak...."': 698,
#  '"not': 699,
#  '"nuisance': 700,
#  '"official"': 701,
#  '"oh': 702,
#  '"okay': 703,
#  '"oligarchs"': 704,
#  '"only': 705,
#  '"opinion".': 706,
#  '"outreach"': 707,
#  '"paano': 708,
#  '"paawa': 709,
#  '"paawa".': 710,
#  '"pabigat"': 711,
#  '"pag': 712,
#  '"paid': 713,
#  '"palpak""manhid""teka-teka"': 714,
#  '"pamasahe"': 715,
#  '"pandak"': 716,
#  '"pandaknognog': 717,
#  '"pandaknognogetc..."': 718,
#  '"pangako': 719,
#  '"pangungupit"': 720,
#  '"papanalo': 721,
#  '"paulit': 722,
#  '"pero': 723,
#  '"piggy': 724,
#  '"pimps/fixers"': 725,
#  '"pinayaman"': 726,
#  '"pipiliin': 727,
#  '"plastic"': 728,
#  '"pls': 729,
#  '"poe': 730,
#  '"porket': 731,
#  '"positive"': 732,
#  '"presidente"': 733,
#  '"privilege"': 734,
#  '"projects"sa': 735,
#  '"putangena': 736,
#  '"putangina': 737,
#  '"pwede': 738,
#  '"quits".': 739,
#  '"rEsPeCt': 740,
#  '"rape': 741,
#  '"rapist"': 742,
#  '"regular"': 743,
#  '"respect': 744,
#  '"retired".': 745,
#  '"rides"': 746,
#  '"roast"': 747,
#  '"sLaYiNg"."yAsSs': 748,
#  '"sa': 749,
#  '"sabotage"?': 750,
#  '"sakang"': 751,
#  '"salvaged"': 752,
#  '"sandro': 753,
#  '"scientific"': 754,
#  '"set': 755,
#  '"severe': 756,
#  '"sex': 757,
#  '"show': 758,
#  '"sige': 759,
#  '"singapore"': 760,
#  '"sino': 761,
#  '"sinungaling': 762,
#  '"so': 763,
#  '"soft': 764,
#  '"spare': 765,
#  '"sponsored"': 766,
#  '"sulong"': 767,
#  '"supporters"': 768,
#  '"sus': 769,
#  '"tangina': 770,
#  '"tattered"': 771,
#  '"teammate"': 772,
#  '"the': 773,
#  '"this': 774,
#  '"today': 775,
#  '"trapo"': 776,
#  '"triggered"': 777,
#  '"turon"': 778,
#  '"tuwid': 779,
#  '"ui': 780,
#  '"under': 781,
#  '"unemployed"?': 782,
#  '"unite"': 783,
#  '"unity': 784,
#  '"unity"': 785,
#  '"vip\'ism"': 786,
#  '"wag': 787,
#  '"wala': 788,
#  '"walang': 789,
#  '"we': 790,
#  '"we"...': 791,
#  '"we."': 792,
#  '"weh?': 793,
#  '"well-mannered': 794,
#  '"why': 795,
#  '"win"': 796,
#  '"wins"': 797,
#  '"with': 798,
#  '"yan': 799,
#  '"yellow".': 800,
#  '"yes': 801,
#  '"you': 802,
#  '#': 803,
#  '#3,': 804,
#  '#6;': 805,
#  '#Angat': 806,
#  '#Inquirer': 807,
#  '#Ipana7o': 808,
#  '#Kulay': 809,
#  '#NAME?': 810,
#  '#Never': 811,
#  '#PBBThe': 812,
#  '#Ph': 813,
#  '#^%*': 814,
#  '$': 815,
#  '$$$': 816,
#  '$.': 817,
#  '$.3M': 818,
#  '$/day.': 819,
#  '$10B': 820,
#  '$10b.': 821,
#  '$200m': 822,
#  '$22million': 823,
#  '$28B': 824,
#  '$40M': 825,
#  '$42million': 826,
#  '$658M.': 827,
#  '$683M': 828,
#  '$81M': 829,
#  '$97K': 830,
#  '$HE': 831,
#  '$_$_$_$': 832,
#  '%': 833,
#  '%!&@#!,': 834,
#  '%.': 835,
#  '%.CNNPresidential': 836,
#  '%sa': 837,
#  '&': 838,
#  '&#x200B': 839,
#  '&#x200B;': 840,
#  '&;': 841,
#  '&Dijillo': 842,
#  '&Vice': 843,
#  '&amp;': 844,
#  '&amp;...': 845,
#  '&amp;decisive': 846,
#  '&amp;escudero': 847,
#  '&amp;not': 848,
#  '&for': 849,
#  '&gt;': 850,
#  '&gt;"BUT"': 851,
#  '&gt;&gt;&gt;': 852,
#  '&gt;&gt;&gt;&gt;': 853,
#  '&gt;&gt;&gt;...': 854,
#  '&gt;&lt;': 855,
#  '&gt;.&lt;': 856,
#  '&gt;:(': 857,
#  '&gt;:D': 858,
#  '&gt;BinayPoeSantiago': 859,
#  '&lt;&lt;watch': 860,
#  '&lt;--': 861,
#  '&lt;/3': 862,
#  '&lt;3': 863,
#  '&lt;insert': 864,
#  '&nbsp;': 865,
#  '&other': 866,
#  '&seconds': 867,
#  "'": 868,
#  "''": 869,
#  "'04I": 870,
#  "'24/7": 871,
#  "'5-6'": 872,
#  "'50s": 873,
#  "'6": 874,
#  "'70": 875,
#  "'Abby": 876,
#  "'Abigail": 877,
#  "'American": 878,
#  "'Bat": 879,
#  "'Big": 880,
#  "'Binay": 881,
#  "'Binay'": 882,
#  "'Bojie'": 883,
#  "'Bong": 884,
#  "'Bongbong'": 885,
#  "'Bongbong-Bong?'": 886,
#  "'CREDIT": 887,
#  "'DI": 888,
#  "'Daang": 889,
#  "'Datu": 890,
#  "'Di": 891,
#  "'Don't": 892,
#  "'Duterte": 893,
#  "'Enabler'": 894,
#  "'FPJ'": 895,
#  "'Fire'": 896,
#  "'GALING": 897,
#  "'Garci'": 898,
#  "'Gustong": 899,
#  '\'Hon."': 900,
#  "'I": 901,
#  "'I'm": 902,
#  "'If": 903,
#  "'Isauli": 904,
#  "'K'": 905,
#  "'KAY": 906,
#  "'Kano": 907,
#  "'Lando'-hit": 908,
#  "'Leni": 909,
#  "'Let": 910,
#  "'Lito'": 911,
#  "'Lo!": 912,
#  "'Lul'": 913,
#  "'M": 914,
#  "'MAGHINTAY": 915,
#  "'MORAL": 916,
#  "'Makati'": 917,
#  "'Manchurian": 918,
#  "'Mar": 919,
#  "'Marcos": 920,
#  "'Nang": 921,
#  "'Never": 922,
#  "'Nognog'": 923,
#  "'Only": 924,
#  "'Only'": 925,
#  "'Pag": 926,
#  "'Pag-usapan": 927,
#  "'Pangako'": 928,
#  "'Pangulo'": 929,
#  "'Panis": 930,
#  "'Pink'": 931,
#  "'Say": 932,
#  "'Some": 933,
#  "'TO!!!": 934,
#  "'TO.": 935,
#  "'TO?": 936,
#  "'The": 937,
#  "'Thinking": 938,
#  "'To": 939,
#  "'Tuwid": 940,
#  "'Two": 941,
#  "'Unfai...via[USERNAME]": 942,
#  "'WAG": 943,
#  "'WAG...": 944,
#  "'Wag": 945,
#  "'Wala": 946,
#  "'We": 947,
#  "'Welcome": 948,
#  "'What": 949,
#  "'YAN": 950,
#  "'YAN!'": 951,
#  "'YO!!!": 952,
#  "'YOLANDA": 953,
#  "'Yan": 954,
#  "'Yolanda'": 955,
#  "'You": 956,
#  "'Yun": 957,
#  "'Yung": 958,
#  "'Zanortehanons'.": 959,
#  "'abominable": 960,
#  "'achievement'...fake": 961,
#  "'ako": 962,
#  "'all": 963,
#  "'alleged'": 964,
#  "'an": 965,
#  "'appreciates'": 966,
#  "'ascending": 967,
#  "'ata": 968,
#  "'attack": 969,
#  "'backs": 970,
#  "'banned": 971,
#  "'bardagulan'": 972,
#  "'be": 973,
#  "'berdugo'": 974,
#  "'blogger'": 975,
#  "'boring'": 976,
#  "'businessman'": 977,
#  "'calculated": 978,
#  "'closet": 979,
#  "'common": 980,
#  "'concert": 981,
#  "'confused'": 982,
#  "'coz": 983,
#  "'d": 984,
#  "'daang": 985,
#  "'datu'": 986,
#  "'daw'": 987,
#  "'dead": 988,
#  "'dear": 989,
#  "'di": 990,
#  "'discouraging'": 991,
#  "'dummy'": 992,
#  "'em": 993,
#  "'feelings'": 994,
#  "'flier'.": 995,
#  "'ha'": 996,
#  "'hakot'": 997,
#  "'hating": 998,
#  "'hay'": 999,
#  ...}

# %%
INDEX_TO_WORD
# Out:
# {0: '',
#  1: '\n\nCNN',
#  2: '\n\nDuterte',
#  3: '\n\nKita',
#  4: '\n\nMAGLABAS',
#  5: '\n\nUlul\nDouble\nStandard',
#  6: '\n\ntangina',
#  7: '\n\nthis',
#  8: '\n\ntw',
#  9: '\n[USERNAME]\n',
#  10: '!',
#  11: '!!',
#  12: '!!!',
#  13: '!!!!',
#  14: '!!!!!',
#  15: '!!!!!!',
#  16: '!!!!!!!!',
#  17: '!!!!!!!!!!!',
#  18: '!!!!Iboboto',
#  19: '!!!!Ipanalo',
#  20: '!!!Leni',
#  21: '!!!Thank',
#  22: '!!![USERNAME]',
#  23: '!!!made',
#  24: '!!!think',
#  25: '!!...',
#  26: '!!EDSA',
#  27: '!!Gagawa',
#  28: '!!InshaAllah',
#  29: '!!Leni',
#  30: '!!ROBREDO',
#  31: '!!Thank',
#  32: '!!anak',
#  33: '!"',
#  34: '!.',
#  35: '!?',
#  36: '!????',
#  37: '!Araw',
#  38: '!BBM',
#  39: '!DI',
#  40: '!Ipanlo',
#  41: '!Kulay',
#  42: '!Layout',
#  43: '!Leni',
#  44: '!Let',
#  45: '!Neri',
#  46: '!Non',
#  47: '!PRAY',
#  48: '!Pampanga',
#  49: '!Panaloang',
#  50: '!Pero',
#  51: '!Youth',
#  52: '![USERNAME]',
#  53: '!artph',
#  54: '!kakampink',
#  55: '!love',
#  56: '!sko',
#  57: '!via[USERNAME]',
#  58: '"',
#  59: '""Andy',
#  60: '""Tito""',
#  61: '"%',
#  62: '"(Photo',
#  63: '"-',
#  64: '"..',
#  65: '"...Binay:',
#  66: '"0.004%"',
#  67: '"250000',
#  68: '"2nd',
#  69: '"3%"',
#  70: '"A',
#  71: '"AKO',
#  72: '"ANO',
#  73: '"AQUINO',
#  74: '"Abnoy',
#  75: '"According',
#  76: '"Actually',
#  77: '"Ah',
#  78: '"Akin',
#  79: '"Ako',
#  80: '"Alam',
#  81: '"All',
#  82: '"Am-Girl"',
#  83: '"American',
#  84: '"And',
#  85: '"Andami',
#  86: '"Ang',
#  87: '"AngatBuhayLahat',
#  88: '"Ano',
#  89: '"Anong',
#  90: '"Anubayan',
#  91: '"Anytime',
#  92: '"Asia\'s',
#  93: '"Asked',
#  94: '"At',
#  95: '"Ate,',
#  96: '"Auto',
#  97: '"Ay',
#  98: '"Ayaw',
#  99: '"Ayoko',
#  100: '"Ayusin',
#  101: '"BA\'T',
#  102: '"BAHALA',
#  103: '"BAYAN',
#  104: '"BBM',
#  105: '"BE',
#  106: '"BEBE',
#  107: '"BINAY',
#  108: '"BINAYIKAW',
#  109: '"BLACK"',
#  110: '"BUB"',
#  111: '"Badjao"s',
#  112: '"Bahala',
#  113: '"Bakit',
#  114: '"Baw',
#  115: '"Bayan',
#  116: '"Bayot"',
#  117: '"Beatles',
#  118: '"Beauty',
#  119: '"Because',
#  120: '"Besidessuch',
#  121: '"Best',
#  122: '"Between',
#  123: '"Bi-Chiz"',
#  124: '"Bilang',
#  125: '"Binay',
#  126: '"Binay"',
#  127: '"Binay:',
#  128: '"Binayhe',
#  129: '"Birds',
#  130: '"Black',
#  131: '"Bobo',
#  132: '"Bongbong"',
#  133: '"Boy',
#  134: '"Bring',
#  135: '"Buksan',
#  136: '"But',
#  137: '"CNN',
#  138: '"Cars',
#  139: '"Condolence',
#  140: '"Cookfest"',
#  141: '"Corrupt"',
#  142: '"Courtesy',
#  143: '"DAHIL',
#  144: '"DIGOY"',
#  145: '"DITO',
#  146: '"DOC"',
#  147: '"DON\'T',
#  148: '"DUTERTE"',
#  149: '"Daang',
#  150: '"Dahil',
#  151: '"Daniel',
#  152: '"Dapat',
#  153: '"Darker',
#  154: '"De',
#  155: '"Decent"?',
#  156: '"Describe',
#  157: '"Desperate',
#  158: '"Di',
#  159: '"Did',
#  160: '"Digong"',
#  161: '"Dilawan"',
#  162: '"Dinaya',
#  163: '"Disqualify',
#  164: '"Do',
#  165: '"Doc',
#  166: '"Doc"',
#  167: '"Don\'t',
#  168: '"Doon',
#  169: '"Dumb',
#  170: '"Duterte',
#  171: '"Duterte"',
#  172: '"Duterte\'s',
#  173: '"Dutertedumarami',
#  174: '"EMERGENCY:',
#  175: '"EXCEPT',
#  176: '"Economist',
#  177: '"Edi',
#  178: '"Even',
#  179: '"Everybody\'s',
#  180: '"Fake',
#  181: '"Fast',
#  182: '"Former',
#  183: '"Formula',
#  184: '"From',
#  185: '"GOOD',
#  186: '"Gagi',
#  187: '"Ganito',
#  188: '"Gapangan"',
#  189: '"Gendeng',
#  190: '"Gentle',
#  191: '"Gobyernong',
#  192: '"God-fearing"',
#  193: '"Good',
#  194: '"Grabe',
#  195: '"Grace',
#  196: '"Gracemag-usap',
#  197: '"Greed."',
#  198: '"Greediest',
#  199: '"Guys',
#  200: '"Guyswag',
#  201: '"HAPPY',
#  202: '"HINDI',
#  203: '"HUMILITY"',
#  204: '"Ha?"',
#  205: '"Hala',
#  206: '"Have',
#  207: '"He',
#  208: '"He\'s',
#  209: '"HelloGuanzi?"',
#  210: '"Help',
#  211: '"Hi',
#  212: '"Higit',
#  213: '"Hiling".',
#  214: '"Hindi',
#  215: '"Hocus',
#  216: '"Hoe',
#  217: '"How',
#  218: '"Hoy',
#  219: '"I',
#  220: '"I""I',
#  221: '"I"?',
#  222: '"I\'m',
#  223: '"IN',
#  224: '"IPAGPAPATULOY',
#  225: '"IPANALO',
#  226: '"ISANG',
#  227: '"Iboboto',
#  228: '"Iboto',
#  229: '"If',
#  230: '"Ika',
#  231: '"Ikaw',
#  232: '"Ilokano',
#  233: '"Im',
#  234: '"Imperial',
#  235: '"Integrity',
#  236: '"Ipagpapatuloy',
#  237: '"Ipanalo',
#  238: '"Is',
#  239: '"Isang',
#  240: '"Isigaw',
#  241: '"Isko',
#  242: '"It',
#  243: '"Ito',
#  244: '"Joey"',
#  245: '"Jusq',
#  246: '"Just',
#  247: '"K"',
#  248: '"KABATAAN',
#  249: '"KAMPANYA',
#  250: '"KATHNIEL"',
#  251: '"Kahirapan',
#  252: '"Kahit',
#  253: '"Kailangan',
#  254: '"Kala',
#  255: '"Katulad',
#  256: '"Kay',
#  257: '"Kaya',
#  258: '"Kids',
#  259: '"Kiko"',
#  260: '"Kilala',
#  261: '"Killer"DuterteGrace',
#  262: '"Kinokondena',
#  263: '"Kita',
#  264: '"Know',
#  265: '"Kris',
#  266: '"Kung',
#  267: '"Kuno"',
#  268: '"Kuya',
#  269: '"LEN',
#  270: '"LIBRE',
#  271: '"LOOSER!!"',
#  272: '"LOVE',
#  273: '"Laban',
#  274: '"Labas',
#  275: '"Laging',
#  276: '"Laki',
#  277: '"Leche',
#  278: '"Leni',
#  279: '"Leni"',
#  280: '"Let',
#  281: '"Libreng',
#  282: '"Lito',
#  283: '"Lito"',
#  284: '"Lonely',
#  285: '"Look',
#  286: '"Loveli-Ness"',
#  287: '"Loyalty"',
#  288: '"MAGNANAKAW"',
#  289: '"MANANALO',
#  290: '"MAR',
#  291: '"MAY',
#  292: '"Ma\'am/lola,',
#  293: '"Madaming',
#  294: '"Mag',
#  295: '"Maganda',
#  296: '"Magbubungaan"',
#  297: '"Magkaisa"',
#  298: '"Maglaba',
#  299: '"Magsasapakan',
#  300: '"Mahal',
#  301: '"Makapoy',
#  302: '"Makati',
#  303: '"Mananalo',
#  304: '"Manchurian',
#  305: '"Manny"',
#  306: '"Mar',
#  307: '"Marami',
#  308: '"Marco"',
#  309: '"Marcos',
#  310: '"Marites"',
#  311: '"Martial',
#  312: '"Maruhas"',
#  313: '"Marunong',
#  314: '"Masyadong',
#  315: '"Matagal',
#  316: '"May',
#  317: '"Maynila"?',
#  318: '"Meron',
#  319: '"Mga',
#  320: '"Micronutrient',
#  321: '"Miriam',
#  322: '"Money',
#  323: '"Move',
#  324: '"Mr.',
#  325: '"Muslim"',
#  326: '"N',
#  327: '"NAGAWA"',
#  328: '"NAGBROWNOUT',
#  329: '"NANAY"',
#  330: '"NO',
#  331: '"NO"',
#  332: '"NOGNOG"',
#  333: '"NaMarcos',
#  334: '"Nagawa',
#  335: '"Nagnakaw',
#  336: '"Nagpakamatay',
#  337: '"Nagpapansin"',
#  338: '"Nakakaoffend',
#  339: '"Nalulungkot',
#  340: '"Nandito',
#  341: '"Napakaraming',
#  342: '"Nasan',
#  343: '"Natutulog',
#  344: '"Nemo',
#  345: '"Nese',
#  346: '"Next',
#  347: '"Ngayon',
#  348: '"Nigger"',
#  349: '"No',
#  350: '"No.',
#  351: '"Nog',
#  352: '"Nog-nog"wag',
#  353: '"Nog-nogpandaklaki',
#  354: '"Nognog',
#  355: '"Nognog"',
#  356: '"Nognog.',
#  357: '"Nognog/pandak"',
#  358: '"NognogPandak"',
#  359: '"NognogPandakLaki',
#  360: '"Nognogpandak\'yan',
#  361: '"Nognogpandakat',
#  362: '"Nognogpandaklaki',
#  363: '"Nognogpandakpero',
#  364: '"Not',
#  365: '"OLNY',
#  366: '"ONLY',
#  367: '"Oayan',
#  368: '"Okay',
#  369: '"Omg',
#  370: '"Only',
#  371: '"Oo',
#  372: '"Oops...',
#  373: '"Ovaltine"',
#  374: '"PANDAK"?',
#  375: '"PARATING',
#  376: '"POEPutangina',
#  377: '"PROTECT',
#  378: '"PROVE',
#  379: '"PUTANGINA',
#  380: '"Paano',
#  381: '"Pag',
#  382: '"Pag"',
#  383: '"Pagbubuo',
#  384: '"Pagmamahal',
#  385: '"Panama"',
#  386: '"Pandak',
#  387: '"Pandak"',
#  388: '"Panday"',
#  389: '"Pang',
#  390: '"Pangit"',
#  391: '"Parot',
#  392: '"Pasalubong"',
#  393: '"Patay',
#  394: '"Patayin',
#  395: '"Paulit-ulit',
#  396: '"Penalty',
#  397: '"Perception',
#  398: '"Pero',
#  399: '"Pet',
#  400: '"PiliBinay"',
#  401: '"Pinansin',
#  402: '"Pinasyal',
#  403: '"Ping"',
#  404: '"Pink',
#  405: '"Pre',
#  406: '"Presidential',
#  407: '"Pride"',
#  408: '"Problema',
#  409: '"Putangina',
#  410: '"RT',
#  411: '"Ready',
#  412: '"Respect',
#  413: '"Ripley\'s',
#  414: '"Robredonaglabas',
#  415: '"Rodrigo',
#  416: '"Rosas"',
#  417: '"Roxas',
#  418: '"Roxas:',
#  419: '"Roxasumikot',
#  420: '"SA',
#  421: '"SD"',
#  422: '"SHE',
#  423: '"SHUT',
#  424: '"SI',
#  425: '"SMNI',
#  426: '"SMNIpresidentialdebatenorbertogonzales',
#  427: '"Sa',
#  428: '"Sakit"',
#  429: '"Salamat',
#  430: '"Sama-sama',
#  431: '"Same-sex',
#  432: '"Seeing',
#  433: '"Sen.',
#  434: '"Shut',
#  435: '"Si',
#  436: '"Sick',
#  437: '"Simpleng',
#  438: '"SinOng',
#  439: '"Sino',
#  440: '"Sinong',
#  441: '"Sirano',
#  442: '"Sonny"',
#  443: '"Sorry',
#  444: '"Special',
#  445: '"Stealing',
#  446: '"Susmaryosep"',
#  447: '"TANGA',
#  448: '"TITO"',
#  449: '"Tama',
#  450: '"Tangna',
#  451: '"Tapatin',
#  452: '"Tatanggalin',
#  453: '"Teacher',
#  454: '"Thank',
#  455: '"The',
#  456: '"There',
#  457: '"There\'s',
#  458: '"They\'re',
#  459: '"This',
#  460: '"Tignan',
#  461: '"Tito"',
#  462: '"Tito""',
#  463: '"To',
#  464: '"Today',
#  465: '"Totoo',
#  466: '"Touch',
#  467: '"Tumatakbo',
#  468: '"U"',
#  469: '"ULING',
#  470: '"UNITY"',
#  471: '"UNSTABLE',
#  472: '"Uling',
#  473: '"Unity"',
#  474: '"Unlike',
#  475: '"Uyy!',
#  476: '"VP',
#  477: '"Vice',
#  478: '"Vicente',
#  479: '"Victory',
#  480: '"WAG',
#  481: '"WALA',
#  482: '"WALANG',
#  483: '"Wag',
#  484: '"Wait',
#  485: '"Wala',
#  486: '"Walang',
#  487: '"We',
#  488: '"What',
#  489: '"Who',
#  490: '"Why',
#  491: '"Why?',
#  492: '"YES',
#  493: '"Yan',
#  494: '"Yes',
#  495: '"YesI',
#  496: '"Yesof',
#  497: '"You',
#  498: '"You\'re',
#  499: '"Your',
#  500: '"Yung',
#  501: '"[USERNAME]:',
#  502: '"[USERNAME]:??',
#  503: '"accomplishments".',
#  504: '"according',
#  505: '"achievement"',
#  506: '"achievements"',
#  507: '"after',
#  508: '"akala',
#  509: '"ako',
#  510: '"alam',
#  511: '"all',
#  512: '"allies"',
#  513: '"among',
#  514: '"anak',
#  515: '"analysis"',
#  516: '"analyze"',
#  517: '"ang',
#  518: '"anti-war',
#  519: '"auntie"',
#  520: '"ay',
#  521: '"bagito"',
#  522: '"baka',
#  523: '"bakit',
#  524: '"bakit?"',
#  525: '"bato-bato',
#  526: '"because',
#  527: '"benefits"',
#  528: '"bias"',
#  529: '"biased"?',
#  530: '"bilang',
#  531: '"binayaran"',
#  532: '"bobo',
#  533: '"bobo"',
#  534: '"borrowings"',
#  535: '"bridge"',
#  536: '"budget',
#  537: '"call',
#  538: '"calling',
#  539: '"cannot',
#  540: '"climate',
#  541: '"competence',
#  542: '"conceive"',
#  543: '"connections"',
#  544: '"convenience',
#  545: '"convicted"',
#  546: '"corrupt"?Wanted',
#  547: '"corrupt?"',
#  548: '"daang',
#  549: '"dahil',
#  550: '"daw"',
#  551: '"daya"',
#  552: '"debate"',
#  553: '"decent"',
#  554: '"degrees"',
#  555: '"desente"',
#  556: '"desperado"',
#  557: '"di',
#  558: '"dinamay".',
#  559: '"dinaya"',
#  560: '"disappeared"',
#  561: '"diskarte"',
#  562: '"do',
#  563: '"don\'t',
#  564: '"dutertards"',
#  565: '"easy',
#  566: '"emergency',
#  567: '"emergency"',
#  568: '"employee',
#  569: '"enhypen',
#  570: '"entertainment',
#  571: '"envelopes""incentives"etc...',
#  572: '"errthang"binay',
#  573: '"flavor',
#  574: '"for',
#  575: '"free',
#  576: '"friends"',
#  577: '"galing"',
#  578: '"galit',
#  579: '"ganito',
#  580: '"golden',
#  581: '"graduate',
#  582: '"great',
#  583: '"great"',
#  584: '"gusto',
#  585: '"gutom"!',
#  586: '"ha"',
#  587: '"habang',
#  588: '"hakot',
#  589: '"hala',
#  590: '"halika',
#  591: '"hanggang',
#  592: '"have',
#  593: '"heartbreaking"',
#  594: '"here',
#  595: '"hideout"',
#  596: '"hijack',
#  597: '"hindi',
#  598: '"honesty',
#  599: '"household',
#  600: '"how',
#  601: '"hugot"',
#  602: '"humbled"',
#  603: '"humming',
#  604: '"huy',
#  605: '"i',
#  606: '"idols"',
#  607: '"if',
#  608: '"in',
#  609: '"indecisive".',
#  610: '"independent',
#  611: '"interesting"',
#  612: '"interviews"',
#  613: '"investment"',
#  614: '"irrelevant"',
#  615: '"it',
#  616: '"itim"',
#  617: '"job',
#  618: '"joking"',
#  619: '"jun',
#  620: '"kahit',
#  621: '"kakampink"',
#  622: '"kami',
#  623: '"kamote"',
#  624: '"kana"chix',
#  625: '"kasalanan',
#  626: '"kase',
#  627: '"katulad',
#  628: '"kaya',
#  629: '"kinain',
#  630: '"kokey"',
#  631: '"komunista"',
#  632: '"korupsyon',
#  633: '"kulelat"',
#  634: '"kung',
#  635: '"kurakot."',
#  636: '"kyah',
#  637: '"lahat',
#  638: '"lahat"',
#  639: '"laki',
#  640: '"lawless"',
#  641: '"lazy""teka-teka"',
#  642: '"legislation"',
#  643: '"liars',
#  644: '"lies',
#  645: '"lies"',
#  646: '"lonely',
#  647: '"loot"',
#  648: '"lutang"',
#  649: '"lutang"Marcos',
#  650: '"m....m...mi-....matuwid',
#  651: '"m4R',
#  652: '"mabuti',
#  653: '"magaling',
#  654: '"magikero."',
#  655: '"magkaiba',
#  656: '"magnanakaw"',
#  657: '"magnanakaw".',
#  658: '"mahabag"',
#  659: '"mahirap',
#  660: '"maitim"',
#  661: '"make',
#  662: '"mamamatay',
#  663: '"mamaya',
#  664: '"mangita',
#  665: '"mar',
#  666: '"marriage',
#  667: '"marwhat',
#  668: '"mas',
#  669: '"matalino',
#  670: '"may',
#  671: '"meryenda',
#  672: '"messiahs"',
#  673: '"mind".',
#  674: '"misstep"',
#  675: '"moneyed"',
#  676: '"more',
#  677: '"most',
#  678: '"murit',
#  679: '"my',
#  680: '"nababad',
#  681: '"nakakatakot"',
#  682: '"nanalo"',
#  683: '"nang".',
#  684: '"nasanay',
#  685: '"natalo',
#  686: '"need',
#  687: '"neutral"',
#  688: '"news"',
#  689: '"ng"',
#  690: '"no',
#  691: '"nog',
#  692: '"nog-nog"',
#  693: '"nognog',
#  694: '"nognog"',
#  695: '"nognog".',
#  696: '"nognogpandakkurakot"',
#  697: '"nognogpandaklaki',
#  698: '"nonogpandak...."',
#  699: '"not',
#  700: '"nuisance',
#  701: '"official"',
#  702: '"oh',
#  703: '"okay',
#  704: '"oligarchs"',
#  705: '"only',
#  706: '"opinion".',
#  707: '"outreach"',
#  708: '"paano',
#  709: '"paawa',
#  710: '"paawa".',
#  711: '"pabigat"',
#  712: '"pag',
#  713: '"paid',
#  714: '"palpak""manhid""teka-teka"',
#  715: '"pamasahe"',
#  716: '"pandak"',
#  717: '"pandaknognog',
#  718: '"pandaknognogetc..."',
#  719: '"pangako',
#  720: '"pangungupit"',
#  721: '"papanalo',
#  722: '"paulit',
#  723: '"pero',
#  724: '"piggy',
#  725: '"pimps/fixers"',
#  726: '"pinayaman"',
#  727: '"pipiliin',
#  728: '"plastic"',
#  729: '"pls',
#  730: '"poe',
#  731: '"porket',
#  732: '"positive"',
#  733: '"presidente"',
#  734: '"privilege"',
#  735: '"projects"sa',
#  736: '"putangena',
#  737: '"putangina',
#  738: '"pwede',
#  739: '"quits".',
#  740: '"rEsPeCt',
#  741: '"rape',
#  742: '"rapist"',
#  743: '"regular"',
#  744: '"respect',
#  745: '"retired".',
#  746: '"rides"',
#  747: '"roast"',
#  748: '"sLaYiNg"."yAsSs',
#  749: '"sa',
#  750: '"sabotage"?',
#  751: '"sakang"',
#  752: '"salvaged"',
#  753: '"sandro',
#  754: '"scientific"',
#  755: '"set',
#  756: '"severe',
#  757: '"sex',
#  758: '"show',
#  759: '"sige',
#  760: '"singapore"',
#  761: '"sino',
#  762: '"sinungaling',
#  763: '"so',
#  764: '"soft',
#  765: '"spare',
#  766: '"sponsored"',
#  767: '"sulong"',
#  768: '"supporters"',
#  769: '"sus',
#  770: '"tangina',
#  771: '"tattered"',
#  772: '"teammate"',
#  773: '"the',
#  774: '"this',
#  775: '"today',
#  776: '"trapo"',
#  777: '"triggered"',
#  778: '"turon"',
#  779: '"tuwid',
#  780: '"ui',
#  781: '"under',
#  782: '"unemployed"?',
#  783: '"unite"',
#  784: '"unity',
#  785: '"unity"',
#  786: '"vip\'ism"',
#  787: '"wag',
#  788: '"wala',
#  789: '"walang',
#  790: '"we',
#  791: '"we"...',
#  792: '"we."',
#  793: '"weh?',
#  794: '"well-mannered',
#  795: '"why',
#  796: '"win"',
#  797: '"wins"',
#  798: '"with',
#  799: '"yan',
#  800: '"yellow".',
#  801: '"yes',
#  802: '"you',
#  803: '#',
#  804: '#3,',
#  805: '#6;',
#  806: '#Angat',
#  807: '#Inquirer',
#  808: '#Ipana7o',
#  809: '#Kulay',
#  810: '#NAME?',
#  811: '#Never',
#  812: '#PBBThe',
#  813: '#Ph',
#  814: '#^%*',
#  815: '$',
#  816: '$$$',
#  817: '$.',
#  818: '$.3M',
#  819: '$/day.',
#  820: '$10B',
#  821: '$10b.',
#  822: '$200m',
#  823: '$22million',
#  824: '$28B',
#  825: '$40M',
#  826: '$42million',
#  827: '$658M.',
#  828: '$683M',
#  829: '$81M',
#  830: '$97K',
#  831: '$HE',
#  832: '$_$_$_$',
#  833: '%',
#  834: '%!&@#!,',
#  835: '%.',
#  836: '%.CNNPresidential',
#  837: '%sa',
#  838: '&',
#  839: '&#x200B',
#  840: '&#x200B;',
#  841: '&;',
#  842: '&Dijillo',
#  843: '&Vice',
#  844: '&amp;',
#  845: '&amp;...',
#  846: '&amp;decisive',
#  847: '&amp;escudero',
#  848: '&amp;not',
#  849: '&for',
#  850: '&gt;',
#  851: '&gt;"BUT"',
#  852: '&gt;&gt;&gt;',
#  853: '&gt;&gt;&gt;&gt;',
#  854: '&gt;&gt;&gt;...',
#  855: '&gt;&lt;',
#  856: '&gt;.&lt;',
#  857: '&gt;:(',
#  858: '&gt;:D',
#  859: '&gt;BinayPoeSantiago',
#  860: '&lt;&lt;watch',
#  861: '&lt;--',
#  862: '&lt;/3',
#  863: '&lt;3',
#  864: '&lt;insert',
#  865: '&nbsp;',
#  866: '&other',
#  867: '&seconds',
#  868: "'",
#  869: "''",
#  870: "'04I",
#  871: "'24/7",
#  872: "'5-6'",
#  873: "'50s",
#  874: "'6",
#  875: "'70",
#  876: "'Abby",
#  877: "'Abigail",
#  878: "'American",
#  879: "'Bat",
#  880: "'Big",
#  881: "'Binay",
#  882: "'Binay'",
#  883: "'Bojie'",
#  884: "'Bong",
#  885: "'Bongbong'",
#  886: "'Bongbong-Bong?'",
#  887: "'CREDIT",
#  888: "'DI",
#  889: "'Daang",
#  890: "'Datu",
#  891: "'Di",
#  892: "'Don't",
#  893: "'Duterte",
#  894: "'Enabler'",
#  895: "'FPJ'",
#  896: "'Fire'",
#  897: "'GALING",
#  898: "'Garci'",
#  899: "'Gustong",
#  900: '\'Hon."',
#  901: "'I",
#  902: "'I'm",
#  903: "'If",
#  904: "'Isauli",
#  905: "'K'",
#  906: "'KAY",
#  907: "'Kano",
#  908: "'Lando'-hit",
#  909: "'Leni",
#  910: "'Let",
#  911: "'Lito'",
#  912: "'Lo!",
#  913: "'Lul'",
#  914: "'M",
#  915: "'MAGHINTAY",
#  916: "'MORAL",
#  917: "'Makati'",
#  918: "'Manchurian",
#  919: "'Mar",
#  920: "'Marcos",
#  921: "'Nang",
#  922: "'Never",
#  923: "'Nognog'",
#  924: "'Only",
#  925: "'Only'",
#  926: "'Pag",
#  927: "'Pag-usapan",
#  928: "'Pangako'",
#  929: "'Pangulo'",
#  930: "'Panis",
#  931: "'Pink'",
#  932: "'Say",
#  933: "'Some",
#  934: "'TO!!!",
#  935: "'TO.",
#  936: "'TO?",
#  937: "'The",
#  938: "'Thinking",
#  939: "'To",
#  940: "'Tuwid",
#  941: "'Two",
#  942: "'Unfai...via[USERNAME]",
#  943: "'WAG",
#  944: "'WAG...",
#  945: "'Wag",
#  946: "'Wala",
#  947: "'We",
#  948: "'Welcome",
#  949: "'What",
#  950: "'YAN",
#  951: "'YAN!'",
#  952: "'YO!!!",
#  953: "'YOLANDA",
#  954: "'Yan",
#  955: "'Yolanda'",
#  956: "'You",
#  957: "'Yun",
#  958: "'Yung",
#  959: "'Zanortehanons'.",
#  960: "'abominable",
#  961: "'achievement'...fake",
#  962: "'ako",
#  963: "'all",
#  964: "'alleged'",
#  965: "'an",
#  966: "'appreciates'",
#  967: "'ascending",
#  968: "'ata",
#  969: "'attack",
#  970: "'backs",
#  971: "'banned",
#  972: "'bardagulan'",
#  973: "'be",
#  974: "'berdugo'",
#  975: "'blogger'",
#  976: "'boring'",
#  977: "'businessman'",
#  978: "'calculated",
#  979: "'closet",
#  980: "'common",
#  981: "'concert",
#  982: "'confused'",
#  983: "'coz",
#  984: "'d",
#  985: "'daang",
#  986: "'datu'",
#  987: "'daw'",
#  988: "'dead",
#  989: "'dear",
#  990: "'di",
#  991: "'discouraging'",
#  992: "'dummy'",
#  993: "'em",
#  994: "'feelings'",
#  995: "'flier'.",
#  996: "'ha'",
#  997: "'hakot'",
#  998: "'hating",
#  999: "'hay'",
#  ...}

# %% [markdown]
# ## Part 2: Getting count of words

# %%
from collections import Counter
from scipy.sparse import csr_matrix

# The three axes of our matrix
row = []
column = []
value = []

for index, sample in enumerate(INPUT_TEXT):

  # Get the count of every word in each sample
  word_count = dict(Counter(sample.split(' ')))

  for word, count in word_count.items():
    # Finding the vocab index of each word in the sample
    # This will represent the column to add the count to
    vocab_index = WORD_TO_INDEX.get(word)

    # When word is found in vocabulary
    if vocab_index >= 0:
      # Determines what's added to the matrix
      # Let the matrix shape be (x, y)
      # At a certain index common to all
      # it will add the sample index to the row (x)
      # then it will add which column the value will be (y)
      # And it tells what is the value, the count, to be added at position (x, y)
      # when we append value
      row.append(index)
      column.append(vocab_index)
      value.append(count)

# %%
countvec_matrix = csr_matrix(
  (value, (row, column)),
  shape=(len(INPUT_TEXT), len(WORD_TO_INDEX))
)

# %%
print(countvec_matrix)
# Out:
#   (0, 6129)	1
#   (0, 24525)	1
#   (0, 32980)	1
#   (0, 34851)	1
#   (0, 40615)	1
#   (0, 50068)	1
#   (0, 55286)	1
#   (0, 63077)	1
#   (0, 67989)	1
#   (1, 2718)	1
#   (1, 3289)	1
#   (1, 4116)	1
#   (1, 4803)	1
#   (1, 6864)	1
#   (1, 11461)	1
#   (1, 15898)	1
#   (1, 16170)	1
#   (1, 16284)	1
#   (1, 16733)	1
#   (1, 17026)	2
#   (1, 17145)	2
#   (1, 17357)	2
#   (1, 21895)	1
#   (1, 24360)	1
#   (1, 26940)	1
#   :	:
#   (28459, 67767)	1
#   (28459, 67989)	2
#   (28459, 68311)	1
#   (28459, 70078)	1
#   (28459, 70087)	1
#   (28459, 71979)	1
#   (28459, 73023)	1
#   (28459, 76759)	1
#   (28460, 990)	1
#   (28460, 19825)	1
#   (28460, 28926)	1
#   (28460, 34667)	1
#   (28460, 47781)	1
#   (28460, 50874)	1
#   (28460, 52382)	1
#   (28460, 57484)	1
#   (28460, 57610)	1
#   (28460, 57788)	1
#   (28460, 59871)	1
#   (28460, 60350)	1
#   (28460, 61899)	1
#   (28460, 62161)	1
#   (28460, 64168)	1
#   (28460, 71826)	1
#   (28460, 72071)	1
